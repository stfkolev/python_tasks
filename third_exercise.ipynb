# %% [markdown]
# # <center> Third exercise for TU-Varna </center>

# %% [markdown]
# ### Importing matplotlib for visualization on Exericse #3

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Exercise #1

# %%
def function(x, y= None):
    if y is None:
        y = []

    y.append(x)
    return y

print(function(1))
print(function(2))
print(function(3))
# Out:
# [1]
# [2]
# [3]

# %% [markdown]
# ### Exercise #2

# %%
with open('test.txt', 'w') as file:
    file.write("I love chocolate very much".replace(' ', '\n'))

with open('test.txt', 'r') as file:
    for line in file.readlines():
        print(line)
# Out:
# I
#
# love
#
# chocolate
#
# very
#
# much

# %% [markdown]
# ### Exercise #3

# %%
xCoordinates = [-2, 2]
yCoordinates = [x * x for x in xCoordinates]

plt.plot(xCoordinates, yCoordinates)
plt.show()
